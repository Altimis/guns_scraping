# %%
from fuzzywuzzy import process
# Out:
# /home/yassine/anaconda3/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
l = [('Locked Loaded', 47.04), ('BattleHawk Armory', 47.58), ('Tactical Surplus USA', 48.37), ('Palmetto State Armory', 48.99), ('DACK Outdoors', 48.99), ('Cheaper Than Dirt', 49.97), ('GunBrand', 49.99), ('GunZoneDeals', 50.99), ('MidwayUSA', 51.84), ('Midway', 51.84), ('Acute Firearms', 53.99), ('Bestow Training Group', 55.99), ('Crusader Arms USA', 55.99), ('Firearms Depot', 56.08), ('Hinterland Outfitters', 57.01), ('GrabAGun.com', 57.79), ('TheGunDock.com', 58.0), ('Sahuarita Guns', 59.99), ('Skunk Bear Tactical', 62.99), ('Optics Planet', 73.59)]

# %%
d = {}

# %%
for x in l:
    d[x] = process.extract(x[0], [x[0] for x in l], limit=len(l))
    
d
# Out:
# {('Locked Loaded', 47.04): [('Locked Loaded', 100),
#   ('the Locked Loaded', 95),
#   ('Hinterland Outfitters', 39),
#   ('TheGunDock.com', 37),
#   ('GunZoneDeals', 32),
#   ('DACK Outdoors', 31),
#   ('Midway', 30),
#   ('Acute Firearms', 30),
#   ('Firearms Depot', 30),
#   ('Palmetto State Armory', 29),
#   ('Tactical Surplus USA', 28),
#   ('Crusader Arms USA', 27),
#   ('GunBrand', 22),
#   ('Optics Planet', 22),
#   ('Bestow Training Group', 21),
#   ('Cheaper Than Dirt', 20),
#   ('BattleHawk Armory', 19),
#   ('MidwayUSA', 18),
#   ('GrabAGun.com', 15),
#   ('Sahuarita Guns', 7),
#   ('Skunk Bear Tactical', 6)],
#  ('BattleHawk Armory', 47.58): [('BattleHawk Armory', 100),
#   ('Palmetto State Armory', 53),
#   ('Acute Firearms', 45),
#   ('Cheaper Than Dirt', 39),
#   ('Midway', 36),
#   ('Crusader Arms USA', 35),
#   ('DACK Outdoors', 33),
#   ('Firearms Depot', 32),
#   ('TheGunDock.com', 32),
#   ('Skunk Bear Tactical', 31),
#   ('MidwayUSA', 28),
# ...

# %%
for c in range(len(d.keys())):
    
    L=d[list(d.keys())[c]]
    
    print("current choice:",list(d.keys())[c])
    print([x for x in L if x[1]>=90]
         )
# Out:
# current choice: ('Locked Loaded', 47.04)
# [('Locked Loaded', 100), ('the Locked Loaded', 95)]
# current choice: ('BattleHawk Armory', 47.58)
# [('BattleHawk Armory', 100)]
# current choice: ('Tactical Surplus USA', 48.37)
# [('Tactical Surplus USA', 100)]
# current choice: ('Palmetto State Armory', 48.99)
# [('Palmetto State Armory', 100)]
# current choice: ('DACK Outdoors', 48.99)
# [('DACK Outdoors', 100)]
# current choice: ('Cheaper Than Dirt', 49.97)
# [('Cheaper Than Dirt', 100)]
# current choice: ('GunBrand', 49.99)
# [('GunBrand', 100)]
# current choice: ('GunZoneDeals', 50.99)
# [('GunZoneDeals', 100)]
# current choice: ('MidwayUSA', 51.84)
# [('MidwayUSA', 100), ('Midway', 90)]
# current choice: ('Midway', 51.84)
# [('Midway', 100), ('MidwayUSA', 90)]
# current choice: ('Acute Firearms', 53.99)
# [('Acute Firearms', 100)]
# current choice: ('Bestow Training Group', 55.99)
# [('Bestow Training Group', 100)]
# current choice: ('Crusader Arms USA', 55.99)
# ...

# %%
# Out:
# [('Locked Loaded', 47.04),
#  ('BattleHawk Armory', 47.58),
#  ('Tactical Surplus USA', 48.37),
#  ('Palmetto State Armory', 48.99),
#  ('DACK Outdoors', 48.99),
#  ('Cheaper Than Dirt', 49.97),
#  ('GunBrand', 49.99),
#  ('GunZoneDeals', 50.99),
#  ('MidwayUSA', 51.84),
#  ('Midway', 51.84),
#  ('Acute Firearms', 53.99),
#  ('Bestow Training Group', 55.99),
#  ('Crusader Arms USA', 55.99),
#  ('Firearms Depot', 56.08),
#  ('Hinterland Outfitters', 57.01),
#  ('GrabAGun.com', 57.79),
#  ('TheGunDock.com', 58.0),
#  ('Sahuarita Guns', 59.99),
#  ('Skunk Bear Tactical', 62.99),
#  ('Optics Planet', 73.59)]
